# %% [markdown]
# # machine larning -- data prep , omiting the data i,e both columns and rows and filling it in by zeros or statisticall
# methods

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df=pd.read_csv('C:/Users/Jayanth/Downloads/UNZIP_FOR_NOTEBOOKS_FINAL/DATA/Ames_Housing_Data.csv')
df
# Out:
#             PID  MS SubClass MS Zoning  Lot Frontage  Lot Area Street Alley  \
# 0     526301100           20        RL         141.0     31770   Pave   NaN
# 1     526350040           20        RH          80.0     11622   Pave   NaN
# 2     526351010           20        RL          81.0     14267   Pave   NaN
# 3     526353030           20        RL          93.0     11160   Pave   NaN
# 4     527105010           60        RL          74.0     13830   Pave   NaN
# ...         ...          ...       ...           ...       ...    ...   ...
# 2925  923275080           80        RL          37.0      7937   Pave   NaN
# 2926  923276100           20        RL           NaN      8885   Pave   NaN
# 2927  923400125           85        RL          62.0     10441   Pave   NaN
# 2928  924100070           20        RL          77.0     10010   Pave   NaN
# 2929  924151050           60        RL          74.0      9627   Pave   NaN
#
# ...

# %%
df.corr()['SalePrice'].sort_values()
# Out:
# PID               -0.246521
# Enclosed Porch    -0.128787
# Kitchen AbvGr     -0.119814
# Overall Cond      -0.101697
# MS SubClass       -0.085092
# Low Qual Fin SF   -0.037660
# Bsmt Half Bath    -0.035835
# Yr Sold           -0.030569
# Misc Val          -0.015691
# BsmtFin SF 2       0.005891
# 3Ssn Porch         0.032225
# Mo Sold            0.035259
# Pool Area          0.068403
# Screen Porch       0.112151
# Bedroom AbvGr      0.143913
# Bsmt Unf SF        0.182855
# Lot Area           0.266549
# 2nd Flr SF         0.269373
# Bsmt Full Bath     0.276050
# Half Bath          0.285056
# Open Porch SF      0.312951
# Wood Deck SF       0.327143
# Lot Frontage       0.357318
# BsmtFin SF 1       0.432914
# Fireplaces         0.474558
# TotRms AbvGrd      0.495474
# Mas Vnr Area       0.508285
# Garage Yr Blt      0.526965
# Year Remod/Add     0.532974
# Full Bath          0.545604
# Year Built         0.558426
# 1st Flr SF         0.621676
# Total Bsmt SF      0.632280
# ...

# %% [markdown]
# the above tells about the correlation of sales parametres to sales data

# %%
sns.scatterplot(x='Overall Qual',y='SalePrice',data=df)
# Out:
# <AxesSubplot:xlabel='Overall Qual', ylabel='SalePrice'>

# %%
## even though the quality is 9 or 10 the price is low

# %%
## lets check with another parametre 
sns.scatterplot(x='Gr Liv Area',y='SalePrice',data=df)
# Out:
# <AxesSubplot:xlabel='Gr Liv Area', ylabel='SalePrice'>

# %%
## the relation is higher the living space higher the price but some houses are cheap

# %%
# lets checq the df of price below 200000 and quality 8 above
df[(df['Overall Qual']>8) & (df['SalePrice']<200000)]
# Out:
#             PID  MS SubClass MS Zoning  Lot Frontage  Lot Area Street Alley  \
# 1182  533350090           60        RL           NaN     24572   Pave   NaN
# 1498  908154235           60        RL         313.0     63887   Pave   NaN
# 2180  908154195           20        RL         128.0     39290   Pave   NaN
# 2181  908154205           60        RL         130.0     40094   Pave   NaN
#
#      Lot Shape Land Contour Utilities  ... Pool Area Pool QC Fence  \
# 1182       IR1          Lvl    AllPub  ...         0     NaN   NaN
# 1498       IR3          Bnk    AllPub  ...       480      Gd   NaN
# 2180       IR1          Bnk    AllPub  ...         0     NaN   NaN
# 2181       IR1          Bnk    AllPub  ...         0     NaN   NaN
#
#      Misc Feature Misc Val Mo Sold Yr Sold  Sale Type  Sale Condition  \
# 1182          NaN        0       6    2008        WD           Family
# 1498          NaN        0       1    2008        New         Partial
# ...

# %%
df[(df['Overall Qual']>7) & (df['SalePrice']<200000)]  ## like this
# Out:
#             PID  MS SubClass MS Zoning  Lot Frontage  Lot Area Street Alley  \
# 7     527145080          120        RL          43.0      5005   Pave   NaN
# 16    527225035           50        RL         152.0     12134   Pave   NaN
# 53    528228440          120        RL          43.0      3182   Pave   NaN
# 106   533253060          120        RL          30.0      4420   Pave   NaN
# 183   902305110           70        RM          60.0      9600   Pave  Grvl
# 298   909455030          120        RM          35.0      3907   Pave   NaN
# 299   909455040          120        RM          35.0      3907   Pave   NaN
# 365   527182110          120        RL           NaN      5814   Pave   NaN
# 478   528240060           80        RL           NaN      7750   Pave   NaN
# 573   533236050          160        FV          24.0      2645   Pave  Pave
# 577   533254110           80        RL          80.0      9600   Pave   NaN
# ...

# %%
# lets checq the df of price below 200000 and quality 8 above
df[(df['Overall Qual']>8) & (df['SalePrice']<200000)]
## these 4 houses if we put them in our model , our model will fail
# Out:
#             PID  MS SubClass MS Zoning  Lot Frontage  Lot Area Street Alley  \
# 1182  533350090           60        RL           NaN     24572   Pave   NaN
# 1498  908154235           60        RL         313.0     63887   Pave   NaN
# 2180  908154195           20        RL         128.0     39290   Pave   NaN
# 2181  908154205           60        RL         130.0     40094   Pave   NaN
#
#      Lot Shape Land Contour Utilities  ... Pool Area Pool QC Fence  \
# 1182       IR1          Lvl    AllPub  ...         0     NaN   NaN
# 1498       IR3          Bnk    AllPub  ...       480      Gd   NaN
# 2180       IR1          Bnk    AllPub  ...         0     NaN   NaN
# 2181       IR1          Bnk    AllPub  ...         0     NaN   NaN
#
#      Misc Feature Misc Val Mo Sold Yr Sold  Sale Type  Sale Condition  \
# 1182          NaN        0       6    2008        WD           Family
# 1498          NaN        0       1    2008        New         Partial
# ...

# %%
df[(df['Gr Liv Area']>4000) & (df['SalePrice']<400000)]
# Out:
#             PID  MS SubClass MS Zoning  Lot Frontage  Lot Area Street Alley  \
# 1498  908154235           60        RL         313.0     63887   Pave   NaN
# 2180  908154195           20        RL         128.0     39290   Pave   NaN
# 2181  908154205           60        RL         130.0     40094   Pave   NaN
#
#      Lot Shape Land Contour Utilities  ... Pool Area Pool QC Fence  \
# 1498       IR3          Bnk    AllPub  ...       480      Gd   NaN
# 2180       IR1          Bnk    AllPub  ...         0     NaN   NaN
# 2181       IR1          Bnk    AllPub  ...         0     NaN   NaN
#
#      Misc Feature Misc Val Mo Sold Yr Sold  Sale Type  Sale Condition  \
# 1498          NaN        0       1    2008        New         Partial
# 2180         Elev    17000      10    2007        New         Partial
# 2181          NaN        0      10    2007        New         Partial
#
#       SalePrice
# 1498     160000
# 2180     183850
# 2181     184750
#
# [3 rows x 81 columns]

# %%
## we need to drop those 3

# %%
df[(df['Gr Liv Area']>4000) & (df['SalePrice']<400000)].index
# Out:
# Int64Index([1498, 2180, 2181], dtype='int64')

# %%
## gives the index number

# %%
ind_drop = df[(df['Gr Liv Area']>4000) & (df['SalePrice']<400000)].index

# %%
## drpiing
df = df.drop(ind_drop,axis=0)

# %%
sns.scatterplot(x='Gr Liv Area',y='SalePrice',data=df)
# Out:
# <AxesSubplot:xlabel='Gr Liv Area', ylabel='SalePrice'>

# %%
## observe in[41], and in[30] we observe the model is some what good

# %%
#df.to_csv("../DATA/Ames_outliers_removed.csv",index=False)

# %%
with open(r'C:\Users\Jayanth\Downloads\UNZIP_FOR_NOTEBOOKS_FINAL\DATA\Ames_Housing_Feature_Description.txt','r') as f: 
    print(f.read())
# Out:
# MSSubClass: Identifies the type of dwelling involved in the sale.
#
#         20	1-STORY 1946 & NEWER ALL STYLES
#         30	1-STORY 1945 & OLDER
#         40	1-STORY W/FINISHED ATTIC ALL AGES
#         45	1-1/2 STORY - UNFINISHED ALL AGES
#         50	1-1/2 STORY FINISHED ALL AGES
#         60	2-STORY 1946 & NEWER
#         70	2-STORY 1945 & OLDER
#         75	2-1/2 STORY ALL AGES
#         80	SPLIT OR MULTI-LEVEL
#         85	SPLIT FOYER
#         90	DUPLEX - ALL STYLES AND AGES
#        120	1-STORY PUD (Planned Unit Development) - 1946 & NEWER
#        150	1-1/2 STORY PUD - ALL AGES
#        160	2-STORY PUD - 1946 & NEWER
#        180	PUD - MULTILEVEL - INCL SPLIT LEV/FOYER
#        190	2 FAMILY CONVERSION - ALL STYLES AND AGES
#
# MSZoning: Identifies the general zoning classification of the sale.
#
#        A	Agriculture
#        C	Commercial
#        FV	Floating Village Residential
#        I	Industrial
#        RH	Residential High Density
#        RL	Residential Low Density
# ...

# %%
## the above one is decscrption of the dataset

# %%
df=pd.read_csv('C:/Users/Jayanth/Downloads/UNZIP_FOR_NOTEBOOKS_FINAL/DATA/Ames_outliers_removed.csv')
df
# Out:
#             PID  MS SubClass MS Zoning  Lot Frontage  Lot Area Street Alley  \
# 0     526301100           20        RL         141.0     31770   Pave   NaN
# 1     526350040           20        RH          80.0     11622   Pave   NaN
# 2     526351010           20        RL          81.0     14267   Pave   NaN
# 3     526353030           20        RL          93.0     11160   Pave   NaN
# 4     527105010           60        RL          74.0     13830   Pave   NaN
# ...         ...          ...       ...           ...       ...    ...   ...
# 2922  923275080           80        RL          37.0      7937   Pave   NaN
# 2923  923276100           20        RL           NaN      8885   Pave   NaN
# 2924  923400125           85        RL          62.0     10441   Pave   NaN
# 2925  924100070           20        RL          77.0     10010   Pave   NaN
# 2926  924151050           60        RL          74.0      9627   Pave   NaN
#
# ...

# %%
# here pid wont show any diff in algoritham so drop it

# %%
df=df.drop('PID',axis=1) ## axis = 1 is coz its a column

# %%
df.head()
# Out:
#    MS SubClass MS Zoning  Lot Frontage  Lot Area Street Alley Lot Shape  \
# 0           20        RL         141.0     31770   Pave   NaN       IR1
# 1           20        RH          80.0     11622   Pave   NaN       Reg
# 2           20        RL          81.0     14267   Pave   NaN       IR1
# 3           20        RL          93.0     11160   Pave   NaN       Reg
# 4           60        RL          74.0     13830   Pave   NaN       IR1
#
#   Land Contour Utilities Lot Config  ... Pool Area Pool QC  Fence  \
# 0          Lvl    AllPub     Corner  ...         0     NaN    NaN
# 1          Lvl    AllPub     Inside  ...         0     NaN  MnPrv
# 2          Lvl    AllPub     Corner  ...         0     NaN    NaN
# 3          Lvl    AllPub     Corner  ...         0     NaN    NaN
# 4          Lvl    AllPub     Inside  ...         0     NaN  MnPrv
#
#   Misc Feature Misc Val Mo Sold  Yr Sold  Sale Type  Sale Condition  SalePrice
# ...

# %%
df.isnull().sum() ## it return null is zero and non null is not zero and it sums
# Out:
# MS SubClass         0
# MS Zoning           0
# Lot Frontage      490
# Lot Area            0
# Street              0
#                  ...
# Mo Sold             0
# Yr Sold             0
# Sale Type           0
# Sale Condition      0
# SalePrice           0
# Length: 80, dtype: int64

# %%
df.isnull()
# Out:
#       MS SubClass  MS Zoning  Lot Frontage  Lot Area  Street  Alley  \
# 0           False      False         False     False   False   True
# 1           False      False         False     False   False   True
# 2           False      False         False     False   False   True
# 3           False      False         False     False   False   True
# 4           False      False         False     False   False   True
# ...           ...        ...           ...       ...     ...    ...
# 2922        False      False         False     False   False   True
# 2923        False      False          True     False   False   True
# 2924        False      False         False     False   False   True
# 2925        False      False         False     False   False   True
# 2926        False      False         False     False   False   True
#
#       Lot Shape  Land Contour  Utilities  Lot Config  ...  Pool Area  Pool QC  \
# ...

# %%
100 * df.isnull().sum() / len(df)  ## it shows the percentage of nulls in the data we need to do it in a function
# Out:
# MS SubClass        0.00000
# MS Zoning          0.00000
# Lot Frontage      16.74069
# Lot Area           0.00000
# Street             0.00000
#                     ...
# Mo Sold            0.00000
# Yr Sold            0.00000
# Sale Type          0.00000
# Sale Condition     0.00000
# SalePrice          0.00000
# Length: 80, dtype: float64

# %%
def percent_missing(df):
    percent_nan = 100* df.isnull().sum() / len(df)
    percent_nan = percent_nan[percent_nan>0].sort_values()
    return percent_nan

# %%
percent_nan = percent_missing(df)
percent_nan
# Out:
# Electrical         0.034165
# Garage Area        0.034165
# Total Bsmt SF      0.034165
# Bsmt Unf SF        0.034165
# BsmtFin SF 1       0.034165
# BsmtFin SF 2       0.034165
# Garage Cars        0.034165
# Bsmt Full Bath     0.068329
# Bsmt Half Bath     0.068329
# Mas Vnr Area       0.785787
# Mas Vnr Type       0.785787
# BsmtFin Type 1     2.733174
# Bsmt Qual          2.733174
# Bsmt Cond          2.733174
# BsmtFin Type 2     2.767339
# Bsmt Exposure      2.835668
# Garage Type        5.363854
# Garage Finish      5.432183
# Garage Qual        5.432183
# Garage Cond        5.432183
# Garage Yr Blt      5.432183
# Lot Frontage      16.740690
# Fireplace Qu      48.582166
# Fence             80.457807
# Alley             93.235395
# Misc Feature      96.412709
# Pool QC           99.590024
# dtype: float64

# %%
sns.barplot(x=percent_nan.index,y=percent_nan)
# Out:
# <AxesSubplot:>

# %%
## the ais is abrupt so
sns.barplot(x=percent_nan.index,y=percent_nan)
plt.xticks(rotation=90);

# %% [markdown]
# # Removing Features or Removing Rows

# %% [markdown]
# If only a few rows relative to the size of your dataset are missing some values, then it might just be a good idea to drop those rows. What does this cost you in terms of performace? It essentialy removes potential training/testing data, but if its only a few rows, its unlikely to change performance.
#
# Sometimes it is a good idea to remove a feature entirely if it has too many null values. However, you should carefully consider why it has so many null values, in certain situations null could just be used as a separate category.
#
# Take for example a feature column for the number of cars that can fit into a garage. Perhaps if there is no garage then there is a null value, instead of a zero. It probably makes more sense to quickly fill the null values in this case with a zero instead of a null. Only you can decide based off your domain expertise and knowledge of the data set!

# %% [markdown]
# # Working based on Rows Missing Data
# Filling in Data or Dropping Data?

# %% [markdown]
# Let's explore how to choose to remove or fill in missing data for rows that are missing some data. Let's choose some threshold where we decide it is ok to drop a row if its missing some data (instead of attempting to fill in that missing data point). We will choose 1% as our threshold. This means if less than 1% of the rows are missing this feature, we will consider just dropping that row, instead of dealing with the feature itself. There is no right answer here, just use common sense and your domain knowledge of the dataset, obviously you don't want to drop a very high threshold like 50% , you should also explore correlation to the dataset, maybe it makes sense to drop the feature instead.
#
# Based on the text description of the features, you will see that most of this missing data is actually NaN on purpose as a placeholder for 0 or "none"

# %%
plt.figure(figsize=(8,4),dpi=200)
sns.barplot(x=percent_nan.index,y=percent_nan)
plt.xticks(rotation=90)
plt.ylim(0,1)  ## this means y limit is 1% max and some values are missed more than 1%
# Out:
# (0.0, 1.0)

# %%
percent_nan[percent_nan<1]
# Out:
# Electrical        0.034165
# Garage Area       0.034165
# Total Bsmt SF     0.034165
# Bsmt Unf SF       0.034165
# BsmtFin SF 1      0.034165
# BsmtFin SF 2      0.034165
# Garage Cars       0.034165
# Bsmt Full Bath    0.068329
# Bsmt Half Bath    0.068329
# Mas Vnr Area      0.785787
# Mas Vnr Type      0.785787
# dtype: float64

# %%
100/len(df)  ## this 0.0341 and lectrical is same what is it saying means only one row is missing
# Out:
# 0.0341646737273659

# %%
df[df['Electrical'].isnull()]  # for cross cheq
# Out:
#       MS SubClass MS Zoning  Lot Frontage  Lot Area Street Alley Lot Shape  \
# 1576           80        RL          73.0      9735   Pave   NaN       Reg
#
#      Land Contour Utilities Lot Config  ... Pool Area Pool QC Fence  \
# 1576          Lvl    AllPub     Inside  ...         0     NaN   NaN
#
#      Misc Feature Misc Val Mo Sold  Yr Sold  Sale Type  Sale Condition  \
# 1576          NaN        0       5     2008        WD           Normal
#
#       SalePrice
# 1576     167500
#
# [1 rows x 80 columns]

# %%
df[df['Bsmt Half Bath'].isnull()]
# Out:
#       MS SubClass MS Zoning  Lot Frontage  Lot Area Street Alley Lot Shape  \
# 1341           20        RM          99.0      5940   Pave   NaN       IR1
# 1497           20        RL         123.0     47007   Pave   NaN       IR1
#
#      Land Contour Utilities Lot Config  ... Pool Area Pool QC  Fence  \
# 1341          Lvl    AllPub        FR3  ...         0     NaN  MnPrv
# 1497          Lvl    AllPub     Inside  ...         0     NaN    NaN
#
#      Misc Feature Misc Val Mo Sold  Yr Sold  Sale Type  Sale Condition  \
# 1341          NaN        0       4     2008      ConLD         Abnorml
# 1497          NaN        0       7     2008        WD           Normal
#
#       SalePrice
# 1341      79000
# 1497     284700
#
# [2 rows x 80 columns]

# %%
df[df['Mas Vnr Type'].isnull()]
# Out:
#       MS SubClass MS Zoning  Lot Frontage  Lot Area Street Alley Lot Shape  \
# 55             60        RL           NaN      7851   Pave   NaN       Reg
# 484            60        RL           NaN     12891   Pave   NaN       IR1
# 517            20        FV          90.0      7993   Pave   NaN       IR1
# 538            20        RL          67.0     10083   Pave   NaN       Reg
# 867            60        RL          70.0      8749   Pave   NaN       Reg
# 1095           60        RL           NaN      7750   Pave   NaN       Reg
# 1119           20        RL          87.0     10037   Pave   NaN       Reg
# 1122           20        FV          95.0     11639   Pave   NaN       Reg
# 1127           60        FV          65.0      8125   Pave   NaN       Reg
# 1184           60        FV           NaN      7500   Pave   NaN       Reg
# 1454           60        RL          75.0      9473   Pave   NaN       Reg
# ...

# %%
df[df['Electrical'].isnull()]['Garage Area']
# Out:
# 1576    400.0
# Name: Garage Area, dtype: float64

# %%
## the missing electrical has garrage value

# %%
## dropping some rows
df = df.dropna(axis=0,subset= ['Electrical','Garage Cars'])

# %%
percent_nan = percent_missing(df)
percent_nan  ## both electrical and garage cars are removed
# Out:
# Bsmt Unf SF        0.034188
# Total Bsmt SF      0.034188
# BsmtFin SF 2       0.034188
# BsmtFin SF 1       0.034188
# Bsmt Full Bath     0.068376
# Bsmt Half Bath     0.068376
# Mas Vnr Type       0.786325
# Mas Vnr Area       0.786325
# Bsmt Qual          2.735043
# Bsmt Cond          2.735043
# BsmtFin Type 1     2.735043
# BsmtFin Type 2     2.769231
# Bsmt Exposure      2.837607
# Garage Type        5.367521
# Garage Qual        5.401709
# Garage Cond        5.401709
# Garage Finish      5.401709
# Garage Yr Blt      5.401709
# Lot Frontage      16.752137
# Fireplace Qu      48.547009
# Fence             80.478632
# Alley             93.230769
# Misc Feature      96.410256
# Pool QC           99.589744
# dtype: float64

# %%
percent_nan = percent_nan<1
percent_nan
# Out:
# Bsmt Unf SF        True
# Total Bsmt SF      True
# BsmtFin SF 2       True
# BsmtFin SF 1       True
# Bsmt Full Bath     True
# Bsmt Half Bath     True
# Mas Vnr Type       True
# Mas Vnr Area       True
# Bsmt Qual         False
# Bsmt Cond         False
# BsmtFin Type 1    False
# BsmtFin Type 2    False
# Bsmt Exposure     False
# Garage Type       False
# Garage Qual       False
# Garage Cond       False
# Garage Finish     False
# Garage Yr Blt     False
# Lot Frontage      False
# Fireplace Qu      False
# Fence             False
# Alley             False
# Misc Feature      False
# Pool QC           False
# dtype: bool

# %%
df[df['Bsmt Half Bath'].isnull()]
# Out:
#       MS SubClass MS Zoning  Lot Frontage  Lot Area Street Alley Lot Shape  \
# 1341           20        RM          99.0      5940   Pave   NaN       IR1
# 1497           20        RL         123.0     47007   Pave   NaN       IR1
#
#      Land Contour Utilities Lot Config  ... Pool Area Pool QC  Fence  \
# 1341          Lvl    AllPub        FR3  ...         0     NaN  MnPrv
# 1497          Lvl    AllPub     Inside  ...         0     NaN    NaN
#
#      Misc Feature Misc Val Mo Sold  Yr Sold  Sale Type  Sale Condition  \
# 1341          NaN        0       4     2008      ConLD         Abnorml
# 1497          NaN        0       7     2008        WD           Normal
#
#       SalePrice
# 1341      79000
# 1497     284700
#
# [2 rows x 80 columns]

# %%
df[df['Bsmt Full Bath'].isnull()]
# Out:
#       MS SubClass MS Zoning  Lot Frontage  Lot Area Street Alley Lot Shape  \
# 1341           20        RM          99.0      5940   Pave   NaN       IR1
# 1497           20        RL         123.0     47007   Pave   NaN       IR1
#
#      Land Contour Utilities Lot Config  ... Pool Area Pool QC  Fence  \
# 1341          Lvl    AllPub        FR3  ...         0     NaN  MnPrv
# 1497          Lvl    AllPub     Inside  ...         0     NaN    NaN
#
#      Misc Feature Misc Val Mo Sold  Yr Sold  Sale Type  Sale Condition  \
# 1341          NaN        0       4     2008      ConLD         Abnorml
# 1497          NaN        0       7     2008        WD           Normal
#
#       SalePrice
# 1341      79000
# 1497     284700
#
# [2 rows x 80 columns]

# %%
df[df['Bsmt Unf SF'].isnull()]
# Out:
#       MS SubClass MS Zoning  Lot Frontage  Lot Area Street Alley Lot Shape  \
# 1341           20        RM          99.0      5940   Pave   NaN       IR1
#
#      Land Contour Utilities Lot Config  ... Pool Area Pool QC  Fence  \
# 1341          Lvl    AllPub        FR3  ...         0     NaN  MnPrv
#
#      Misc Feature Misc Val Mo Sold  Yr Sold  Sale Type  Sale Condition  \
# 1341          NaN        0       4     2008      ConLD         Abnorml
#
#       SalePrice
# 1341      79000
#
# [1 rows x 80 columns]

# %%
## all teh above have bsmt 1341 has so we will think we can easily drop that but , only reading document we cannot drop it
## the bsmt have certain value so fill it in 
# we have BSMT have 2 types of columns string and numeric columns

# %%
## BSMT NUMERIC COLUMNS --- FILL NA WITH 0
## BSMT STRING COLUMNS ----FILL WITH none

# %%
## bsmt numeric
bsmt_num_cols = ['BsmtFin SF 1', 'BsmtFin SF 2', 'Bsmt Unf SF','Total Bsmt SF', 'Bsmt Full Bath', 'Bsmt Half Bath']
df[bsmt_num_cols] = df[bsmt_num_cols].fillna(0)

# %%
## string columns

# %%
bsmt_str_cols =  ['Bsmt Qual', 'Bsmt Cond', 'Bsmt Exposure', 'BsmtFin Type 1', 'BsmtFin Type 2']
df[bsmt_str_cols] = df[bsmt_str_cols].fillna('None')

# %%
df[df['Bsmt Unf SF'].isnull()]  ## to cheq
# Out:
# Empty DataFrame
# ...

# %%
percent_nan = percent_missing(df)
plt.figure(figsize=(8,4),dpi=200)
sns.barplot(x=percent_nan.index,y=percent_nan)
plt.xticks(rotation=90)
plt.ylim(0,1)  ## this means y limit is 1% max and some values are missed more than 1%
# Out:
# (0.0, 1.0)

# %%
## so we have mas vnr and mas vnr area are having nulls

# %%
df['Mas Vnr Type']=df['Mas Vnr Area'].fillna('None')# ---- wrongly done

# %% [markdown]
# df['Mas Vnr Type']=df['Mas Vnr Type']

# %%
df["Mas Vnr Type"] = df["Mas Vnr Type"].fillna('None')
df["Mas Vnr Area"] = df["Mas Vnr Area"].fillna(0)

# %%
df
# Out:
#       MS SubClass MS Zoning  Lot Frontage  Lot Area Street Alley Lot Shape  \
# 0              20        RL         141.0     31770   Pave   NaN       IR1
# 1              20        RH          80.0     11622   Pave   NaN       Reg
# 2              20        RL          81.0     14267   Pave   NaN       IR1
# 3              20        RL          93.0     11160   Pave   NaN       Reg
# 4              60        RL          74.0     13830   Pave   NaN       IR1
# ...           ...       ...           ...       ...    ...   ...       ...
# 2922           80        RL          37.0      7937   Pave   NaN       IR1
# 2923           20        RL           NaN      8885   Pave   NaN       IR1
# 2924           85        RL          62.0     10441   Pave   NaN       Reg
# 2925           20        RL          77.0     10010   Pave   NaN       Reg
# 2926           60        RL          74.0      9627   Pave   NaN       Reg
#
# ...

# %%
#percent_nan = percent_missing(df)
plt.figure(figsize=(8,4),dpi=200)
sns.barplot(x=percent_nan.index,y=percent_nan)
plt.xticks(rotation=90)
#plt.ylim(0,7)  ## this means y limit is 1% max and some values are missed more than 1%
# Out:
# (array([0, 1, 2, 3, 4, 5]),
#  [Text(0, 0, 'Lot Frontage'),
#   Text(1, 0, 'Fireplace Qu'),
#   Text(2, 0, 'Fence'),
#   Text(3, 0, 'Alley'),
#   Text(4, 0, 'Misc Feature'),
#   Text(5, 0, 'Pool QC')])

# %%
## up to now we dealt with on;y 1-2% data that have nulls

# %%
## but now we have so muchnow

# %% [markdown]
# # filling missing columns

# %% [markdown]
# Our previous approaches were based more on rows missing data, now we will take an approach based on the column features themselves, since larger percentages of the data appears to be missing.

# %%
## filling the missing data , some times we can put zero [ist approach]but some times at age columns and time column we cannont put that
## we have to use statistical methods[2nd approach]
# we need to see both the aprocahes , in the data set most nan values are nan are zeros , but we need to use 2 approhes

# %%
## when we see the data garage columns are 5 , look that in descrption , u can identify

# %%
df[['Garage Type', 'Garage Finish', 'Garage Qual', 'Garage Cond']] ## garage year is numeracial column
# Out:
#      Garage Type Garage Finish Garage Qual Garage Cond
# 0         Attchd           Fin          TA          TA
# 1         Attchd           Unf          TA          TA
# 2         Attchd           Unf          TA          TA
# 3         Attchd           Fin          TA          TA
# 4         Attchd           Fin          TA          TA
# ...          ...           ...         ...         ...
# 2922      Detchd           Unf          TA          TA
# 2923      Attchd           Unf          TA          TA
# 2924         NaN           NaN         NaN         NaN
# 2925      Attchd           RFn          TA          TA
# 2926      Attchd           Fin          TA          TA
#
# [2925 rows x 4 columns]

# %%
gar_str_cols = ['Garage Type', 'Garage Finish', 'Garage Qual', 'Garage Cond']
df[gar_str_cols] = df[gar_str_cols].fillna('None')

# %%
df['Garage Yr Blt'] = df['Garage Yr Blt'].fillna(0)

# %%
## in the above one year cannot be zero , it should be the mean() of garage opening year , 
# but since it has no garrage so no problem

# %%
percent_nan = percent_missing(df)
plt.figure(figsize=(8,4),dpi=200)
sns.barplot(x=percent_nan.index,y=percent_nan)
plt.xticks(rotation=90)
#plt.ylim(0,7)  ## this means y limit is 1% max and some
# Out:
# (array([0, 1, 2, 3, 4, 5]),
#  [Text(0, 0, 'Lot Frontage'),
#   Text(1, 0, 'Fireplace Qu'),
#   Text(2, 0, 'Fence'),
#   Text(3, 0, 'Alley'),
#   Text(4, 0, 'Misc Feature'),
#   Text(5, 0, 'Pool QC')])

# %% [markdown]
# # dropping feature columns

# %% [markdown]
# Sometimes you may want to take the approach that above a certain missing percentage threshold, you will simply remove the feature from all the data. For example if 99% of rows are missing a feature, it will not be predictive, since almost all the data does not have any value for it. In our particular data set, many of these high percentage NaN features are actually plasceholders for "none" or 0. But for the sake of showing variations on dealing with missing data, we will remove these features, instead of filling them in with the appropriate value

# %%
df[['Lot Frontage', 'Fireplace Qu', 'Fence', 'Alley', 'Misc Feature','Pool QC']]
# Out:
#       Lot Frontage Fireplace Qu  Fence Alley Misc Feature Pool QC
# 0            141.0           Gd    NaN   NaN          NaN     NaN
# 1             80.0          NaN  MnPrv   NaN          NaN     NaN
# 2             81.0          NaN    NaN   NaN         Gar2     NaN
# 3             93.0           TA    NaN   NaN          NaN     NaN
# 4             74.0           TA  MnPrv   NaN          NaN     NaN
# ...            ...          ...    ...   ...          ...     ...
# 2922          37.0          NaN  GdPrv   NaN          NaN     NaN
# 2923           NaN          NaN  MnPrv   NaN          NaN     NaN
# 2924          62.0          NaN  MnPrv   NaN         Shed     NaN
# 2925          77.0           TA    NaN   NaN          NaN     NaN
# 2926          74.0           TA    NaN   NaN          NaN     NaN
#
# [2925 rows x 6 columns]

# %%
df = df.drop(['Pool QC','Misc Feature','Alley','Fence'],axis=1)  ## axis =1 coz it is a column

# %%
percent_nan=percent_missing(df)
sns.barplot(x=percent_nan.index,y=percent_nan)
plt.xticks(rotation=90);

# %%
## the above 2 rows are we cannot drop the rows or we cannot drop the columns too
## we meed to work on them

# %%
## so ltes look

# %%
df['Fireplace Qu'].value_counts()  ## it shows how many a value shown how many times
# so we can fill it in none
# Out:
# Gd    741
# TA    600
# Fa     75
# Po     46
# Ex     43
# Name: Fireplace Qu, dtype: int64

# %%
df['Fireplace Qu']=df['Fireplace Qu'].fillna('None')

# %%
## but this lot fruntage column cannot be filled by none or zero

# %%
## itmst be filled by only crtain nunmerical values only

# %%
## this lot frontage value is dependent on neighboorhood column , ie if we see the description then we can know about it

# %% [markdown]
# LotFrontage: Linear feet of street connected to property
# Neighborhood: Physical locations within Ames city limits
#
#        Blmngtn	Bloomington Heights
#        Blueste	Bluestem
#        BrDale	Briardale
#        BrkSide	Brookside
#        ClearCr	Clear Creek
#        CollgCr	College Creek
#        Crawfor	Crawford
#        Edwards	Edwards
#        Gilbert	Gilbert
#        IDOTRR	Iowa DOT and Rail Road
#        MeadowV	Meadow Village
#        Mitchel	Mitchell
#        Names	North Ames
#        NoRidge	Northridge
#        NPkVill	Northpark Villa
#        NridgHt	Northridge Heights
#        NWAmes	Northwest Ames
#        OldTown	Old Town
#        SWISU	South & West of Iowa State University
#        Sawyer	Sawyer
#        SawyerW	Sawyer West
#        Somerst	Somerset
#        StoneBr	Stone Brook
#        Timber	Timberland
#        Veenker	Veenker

# %% [markdown]
# ## so to fill in the values we need to put mean() values of neighboorhood group by lot frontage
# We will operate under the assumption that the Lot Frontage is related to what neighborhood a house is in.

# %%
plt.figure(figsize=(8,12))
sns.boxplot(x='Lot Frontage',y='Neighborhood',data=df,orient='h')
# Out:
# <AxesSubplot:xlabel='Lot Frontage', ylabel='Neighborhood'>

# %%
df.groupby('Neighborhood')['Lot Frontage'].mean()
# Out:
# Neighborhood
# Blmngtn    46.900000
# Blueste    27.300000
# BrDale     21.500000
# BrkSide    55.789474
# ClearCr    88.150000
# CollgCr    71.336364
# Crawfor    69.951807
# Edwards    64.794286
# Gilbert    74.207207
# Greens     41.000000
# GrnHill          NaN
# IDOTRR     62.383721
# Landmrk          NaN
# MeadowV    25.606061
# Mitchel    75.144444
# NAmes      75.210667
# NPkVill    28.142857
# NWAmes     81.517647
# NoRidge    91.629630
# NridgHt    84.184049
# OldTown    61.777293
# SWISU      59.068182
# Sawyer     74.551020
# SawyerW    70.669811
# Somerst    64.549383
# StoneBr    62.173913
# Timber     81.303571
# Veenker    72.000000
# Name: Lot Frontage, dtype: float64

# %%
df.groupby('Neighborhood')['Lot Frontage'].transform(lambda val: val.fillna(val.mean()))
## learn about this
# Out:
# 0       141.000000
# 1        80.000000
# 2        81.000000
# 3        93.000000
# 4        74.000000
#            ...
# 2922     37.000000
# 2923     75.144444
# 2924     62.000000
# 2925     77.000000
# 2926     74.000000
# Name: Lot Frontage, Length: 2925, dtype: float64

# %%
df['Lot Frontage'].isnull().sum()
# Out:
# 3

# %%
df['Lot Frontage'] = df.groupby('Neighborhood')['Lot Frontage'].transform(lambda val: val.fillna(val.mean()))

# %%
df['Lot Frontage'].isnull().sum()
# Out:
# 3

# %%
## even we pit mean values we still get 3 nan values so we need to put them as zeros
df['Lot Frontage'] = df['Lot Frontage'].fillna(0)

# %%
df['Lot Frontage'].isnull().sum()
# Out:
# 0

# %%
df.to_csv('D:\my_ames_nonull.csv')

# %% [markdown]
# ## now we have no nulls and all are cleaned data

# %%
>>> import numpy as np
>>> from sklearn.impute import KNNImputer
>>> nan = np.nan
>>> X = [[1, 2, nan], [3, 4, 3], [nan, 6, 5], [8, 8, 7]]
>>> imputer = KNNImputer(n_neighbors=2, weights="uniform")
>>> imputer.fit_transform(X)
# Out:
# array([[1. , 2. , 4. ],
#        [3. , 4. , 3. ],
#        [5.5, 6. , 5. ],
#        [8. , 8. , 7. ]])

# %%
X=df[['Lot Frontage']]

# %%
X
# Out:
#       Lot Frontage
# 0       141.000000
# 1        80.000000
# 2        81.000000
# 3        93.000000
# 4        74.000000
# ...            ...
# 2922     37.000000
# 2923     75.144444
# 2924     62.000000
# 2925     77.000000
# 2926     74.000000
#
# [2925 rows x 1 columns]

# %%
df.select_dtypes(include='object')
# Out:
#      MS Zoning Street Lot Shape Land Contour Utilities Lot Config Land Slope  \
# 0           RL   Pave       IR1          Lvl    AllPub     Corner        Gtl
# 1           RH   Pave       Reg          Lvl    AllPub     Inside        Gtl
# 2           RL   Pave       IR1          Lvl    AllPub     Corner        Gtl
# 3           RL   Pave       Reg          Lvl    AllPub     Corner        Gtl
# 4           RL   Pave       IR1          Lvl    AllPub     Inside        Gtl
# ...        ...    ...       ...          ...       ...        ...        ...
# 2922        RL   Pave       IR1          Lvl    AllPub    CulDSac        Gtl
# 2923        RL   Pave       IR1          Low    AllPub     Inside        Mod
# 2924        RL   Pave       Reg          Lvl    AllPub     Inside        Gtl
# 2925        RL   Pave       Reg          Lvl    AllPub     Inside        Mod
# 2926        RL   Pave       Reg          Lvl    AllPub     Inside        Mod
#
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 2925 entries, 0 to 2926
# Data columns (total 76 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   MS SubClass      2925 non-null   int64
#  1   MS Zoning        2925 non-null   object
#  2   Lot Frontage     2925 non-null   float64
#  3   Lot Area         2925 non-null   int64
#  4   Street           2925 non-null   object
#  5   Lot Shape        2925 non-null   object
#  6   Land Contour     2925 non-null   object
#  7   Utilities        2925 non-null   object
#  8   Lot Config       2925 non-null   object
#  9   Land Slope       2925 non-null   object
#  10  Neighborhood     2925 non-null   object
#  11  Condition 1      2925 non-null   object
#  12  Condition 2      2925 non-null   object
#  13  Bldg Type        2925 non-null   object
#  14  House Style      2925 non-null   object
#  15  Overall Qual     2925 non-null   int64
# ...

# %%
df_nums = df.select_dtypes(exclude='object')
df_objs = df.select_dtypes(include='object')
